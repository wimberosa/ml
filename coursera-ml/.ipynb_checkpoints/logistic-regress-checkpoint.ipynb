# %% [markdown]
# Multi-variable logistic regression gradient descent algorithm for
# https://www.coursera.org/learn/machine-learning/home/week/3

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets
import numpy as np
from numpy.linalg import inv

# %matplotlib inline

# %%
class LogisticRegressor():
    
    def __init__(self, X, y, theta):
        self._X     = X
        self._y     = y
        self._m     = X.shape[0]
        self._theta = theta
    
    def computeCost(self):
        # hypothesis is
        #   h0(x) = 1 / (1 + exp(-(theta(0) * x(0) + theta(1) * x(1) + ... + theta(n) * x(n))))
        # where x(0) = 1
        # 
        # or more concisely
        #   h0(x) = 1 / (1 + e^(-theta.T * x))
        #
        inner = np.dot(self._X, self._theta)
        h_theta_x = 1 / (1 + np.exp(-inner))
        
        sum = np.sum(self._y * np.log(h_theta_x) + ((1 - self._y) * np.log(1 - h_theta_x)))
        return -(sum / self._m)
    # end of computeCost
    
    def predict(self, xin):
        # column 0 should be Ones
        assert (xin[0] == 1)
        inner = np.dot(xin, self._theta)
        return (1 / (1 + np.exp(-inner)))
    
    def gradientDescent(self, alpha, iters):
        
        # how many thetas are we computing. Theta is
        # a column vector
        ntheta = self._theta.shape[0]
        
        cost = np.zeros(iters)
        
        # for maximum number of gradient descent
        # iterations
        for ndescent in range(iters):
       
            # hypothesis is
            #   h0(x) = 1 / (1 + exp(-(theta(0) * x(0) + theta(1) * x(1) + ... + theta(n) * x(n))))
            # where x(0) = 1
            # 
            # or more concisely
            #   h0(x) = 1 / (1 + e^(-theta.T * x))
            #
            inner     = np.dot(self._X, self._theta)
            h_theta_x = 1 / (1 + np.exp(-inner))
            error     = h_theta_x - self._y
            
            #print("X=",self._X[:10,:])
            #print("theta=", self._theta)
            #print("X dot theta=", inner[:10])
            #print("y=", self._y[:10])
            #print("error=", error[:10])
            
            # for each theta
            for j in range(ntheta):
              
                # Select the X column for feature (j) which returns
                # an flattened array of one row.   Multiply corresponding
                # elements of error * row and sum them
                # 
                sum = np.sum(np.multiply(error.ravel(), self._X[:,j]))
               
                # We've already used prior theta for computing 
                # each samples error.  Thus this assignment to
                # theta doesn't affect any interim calculations
                # (i.e. adheres to simultaneous theta update)
                #
                self._theta[j,0] = self._theta[j,0] - (alpha * sum)
            # end for j

            cost[ndescent] = self.computeCost()
        # end for ndescent

        return self._theta, cost
    # end gradientDescent

# %%
iris = datasets.load_iris()
X = iris.data 
y = iris.target

# turn it into a column vector
y = np.reshape(y, (len(y), 1))

print("X shape=", X.shape, "features=", iris.feature_names)
print("targets=", iris.target_names)
print("y shape=", y.shape)
#print("X[:5]=", X[:5])

yversus = [] 

# produce new copies of target arrays for each unique
# value in the target namespace.  Each of these
# new arrays will have their y values changed to be
# either (1) or (0).  If y is set to 1 then this
# sample represents a positive example of features for 
# the specific target name.   
#
# E.G. target_names = [ 'zero', 'one', 'two' ]
#      targets      = [ 0, 0, 0, 2, 2, 2, 2, 1, 1]
#      ydict['one'] = [ 0, 0, 0, 0, 0, 0, 0, 1, 1]
#     ydict['zero'] = [ 1, 1, 1, 0, 0, 0, 0, 0, 0]
#      ydict['two'] = [ 0, 0, 0, 1, 1, 1, 1, 0, 0]
#
# What we're producing here is multiple sets of target values so
# that we can run multiple iterations of logistic regression
# building hypothesis (unique theta values) for each unique target
# name.   Basically this is the "one versus the rest" approach
# for logistic regression
# 
for i in range(len(iris.target_names)):
    mask = np.copy(y)
    mask[:][y == i] = 1
    mask[:][y != i] = 0
    yversus.append(mask)

# At column 0 insert a Ones column
XOnes = np.insert(X, 0, 1, axis=1)
#print("XOnes[:5]=", XOnes[:5])
# Out:
# X shape= (150, 4) features= ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
# targets= ['setosa' 'versicolor' 'virginica']
# y shape= (150, 1)

# %%
# Lets take a look at the clustering depending on the
# different features
#
pltColors = [ ( 'r', 'g', 'b', 'c', 'm', 'k' )[i] for i in y.ravel() ]
for xindex, yindex in zip(range(X.shape[1]), range(1, X.shape[1])):

    plt.scatter(X[:,xindex], X[:,yindex], color=pltColors, marker='o', label='iris')

    plt.xlabel(iris.feature_names[xindex])
    plt.ylabel(iris.feature_names[yindex])

    plt.legend(loc='upper right')
    plt.show()

# %%
alpha = 0.001
iters = 100
steps = 10
theta = [0] * len(yversus)
gd    = [0] * len(yversus)

# multiple gradient descent classes and 
# thetas.  One for each type of target
for i in range(len(yversus)):
    
    # make theta a column vector of X feature length
    theta[i] = np.zeros(shape=(XOnes.shape[1], 1))
    gd[i]    = LogisticRegressor(XOnes, yversus[i], theta[i])

    plt.xlabel('iterations')
    plt.ylabel('cost')
    costy = []

    for s in range(0, steps):
        g, cost = gd[i].gradientDescent(alpha, iters)
        costy = costy + cost.tolist()
        
    print(g)
    plt.plot(list(range(0, steps*iters)), costy, linestyle="-", color='r', linewidth=2.5, label='cost')
    plt.legend(loc='upper right')
    plt.show()
# Out:
# [[ 0.36844154]
#  [ 0.58201217]
#  [ 1.97510382]
#  [-3.09197912]
#  [-1.4096697 ]]
# [[ 1.21201799]
#  [ 0.65225954]
#  [-2.00565532]
#  [ 0.63938078]
#  [-1.83422418]]
# [[-1.50655979]
#  [-2.43920993]
#  [-2.20188579]
#  [ 3.54933878]
#  [ 3.43890588]]

# %%
# Now lets check out our prediction versus actual
# and the confidence.   We're effectively checking
# each of our LinearRegressors to see which one
# of them have the most confidence that the sample
# is in their classified group
#
for i in range(XOnes.shape[0]):
    py = 0.0
    for j in range(len(gd)):
        ptmp = gd[j].predict(XOnes[i])
        if (ptmp > py):
            py = ptmp
            pj = j
        
    if (y[i] != pj):
        print("actual=", y[i], "prediction=", pj, "confidence=", py, "<====Prediction error!")
    else:
        print("actual=", y[i], "prediction=", pj, "confidence=", py)
# Out:
# actual= [0] prediction= 0 confidence= [ 0.99645569]
# actual= [0] prediction= 0 confidence= [ 0.98938597]
# actual= [0] prediction= 0 confidence= [ 0.99407554]
# actual= [0] prediction= 0 confidence= [ 0.98591718]
# actual= [0] prediction= 0 confidence= [ 0.99691518]
# actual= [0] prediction= 0 confidence= [ 0.9954767]
# actual= [0] prediction= 0 confidence= [ 0.99336921]
# actual= [0] prediction= 0 confidence= [ 0.99378128]
# actual= [0] prediction= 0 confidence= [ 0.98281513]
# actual= [0] prediction= 0 confidence= [ 0.98968908]
# actual= [0] prediction= 0 confidence= [ 0.9972661]
# actual= [0] prediction= 0 confidence= [ 0.99051349]
# actual= [0] prediction= 0 confidence= [ 0.99022083]
# actual= [0] prediction= 0 confidence= [ 0.99480196]
# actual= [0] prediction= 0 confidence= [ 0.99952524]
# actual= [0] prediction= 0 confidence= [ 0.99923474]
# actual= [0] prediction= 0 confidence= [ 0.99868259]
# actual= [0] prediction= 0 confidence= [ 0.99592132]
# actual= [0] prediction= 0 confidence= [ 0.99597838]
# actual= [0] prediction= 0 confidence= [ 0.99692456]
# actual= [0] prediction= 0 confidence= [ 0.99088215]
# actual= [0] prediction= 0 confidence= [ 0.99569109]
# actual= [0] prediction= 0 confidence= [ 0.99886746]
# actual= [0] prediction= 0 confidence= [ 0.9800299]
# actual= [0] prediction= 0 confidence= [ 0.97635694]
# actual= [0] prediction= 0 confidence= [ 0.98156167]
# actual= [0] prediction= 0 confidence= [ 0.98882481]
# actual= [0] prediction= 0 confidence= [ 0.99544908]
# actual= [0] prediction= 0 confidence= [ 0.99592805]
# actual= [0] prediction= 0 confidence= [ 0.98515492]
# actual= [0] prediction= 0 confidence= [ 0.98297367]
# actual= [0] prediction= 0 confidence= [ 0.99347017]
# actual= [0] prediction= 0 confidence= [ 0.99878754]
# actual= [0] prediction= 0 confidence= [ 0.99929333]
# actual= [0] prediction= 0 confidence= [ 0.98968908]
# actual= [0] prediction= 0 confidence= [ 0.99633964]
# actual= [0] prediction= 0 confidence= [ 0.99793563]
# actual= [0] prediction= 0 confidence= [ 0.98968908]
# actual= [0] prediction= 0 confidence= [ 0.98957532]
# actual= [0] prediction= 0 confidence= [ 0.99413082]
# actual= [0] prediction= 0 confidence= [ 0.99682381]
# actual= [0] prediction= 0 confidence= [ 0.95638508]
# actual= [0] prediction= 0 confidence= [ 0.99295327]
# actual= [0] prediction= 0 confidence= [ 0.98785235]
# actual= [0] prediction= 0 confidence= [ 0.98791307]
# actual= [0] prediction= 0 confidence= [ 0.987077]
# actual= [0] prediction= 0 confidence= [ 0.99636316]
# actual= [0] prediction= 0 confidence= [ 0.99146768]
# actual= [0] prediction= 0 confidence= [ 0.99710274]
# actual= [0] prediction= 0 confidence= [ 0.99443479]
# actual= [1] prediction= 1 confidence= [ 0.44940218]
# actual= [1] prediction= 1 confidence= [ 0.28787221]
# actual= [1] prediction= 1 confidence= [ 0.46921571]
# actual= [1] prediction= 1 confidence= [ 0.58891211]
# actual= [1] prediction= 1 confidence= [ 0.506421]
# actual= [1] prediction= 1 confidence= [ 0.45184585]
# actual= [1] prediction= 1 confidence= [ 0.22669317]
# actual= [1] prediction= 1 confidence= [ 0.46760777]
# actual= [1] prediction= 1 confidence= [ 0.56394558]
# actual= [1] prediction= 1 confidence= [ 0.291971]
# actual= [1] prediction= 1 confidence= [ 0.70383216]
# actual= [1] prediction= 1 confidence= [ 0.26453027]
# actual= [1] prediction= 1 confidence= [ 0.80790159]
# actual= [1] prediction= 1 confidence= [ 0.45303302]
# actual= [1] prediction= 1 confidence= [ 0.26222236]
# actual= [1] prediction= 1 confidence= [ 0.40371417]
# actual= [1] prediction= 2 confidence= [ 0.34492801] <====Prediction error!
# actual= [1] prediction= 1 confidence= [ 0.59075587]
# actual= [1] prediction= 1 confidence= [ 0.72501239]
# actual= [1] prediction= 1 confidence= [ 0.58090061]
# actual= [1] prediction= 2 confidence= [ 0.5702629] <====Prediction error!
# actual= [1] prediction= 1 confidence= [ 0.4373308]
# actual= [1] prediction= 1 confidence= [ 0.66568754]
# actual= [1] prediction= 1 confidence= [ 0.59362874]
# actual= [1] prediction= 1 confidence= [ 0.48373688]
# actual= [1] prediction= 1 confidence= [ 0.43667355]
# actual= [1] prediction= 1 confidence= [ 0.63010374]
# actual= [1] prediction= 1 confidence= [ 0.4119073]
# actual= [1] prediction= 1 confidence= [ 0.36240337]
# actual= [1] prediction= 1 confidence= [ 0.52966564]
# actual= [1] prediction= 1 confidence= [ 0.59817653]
# actual= [1] prediction= 1 confidence= [ 0.62652963]
# actual= [1] prediction= 1 confidence= [ 0.46813574]
# actual= [1] prediction= 2 confidence= [ 0.82009131] <====Prediction error!
# actual= [1] prediction= 2 confidence= [ 0.46168342] <====Prediction error!
# actual= [1] prediction= 1 confidence= [ 0.14789616]
# actual= [1] prediction= 1 confidence= [ 0.40573595]
# actual= [1] prediction= 1 confidence= [ 0.7571339]
# actual= [1] prediction= 1 confidence= [ 0.28591146]
# actual= [1] prediction= 1 confidence= [ 0.48958622]
# actual= [1] prediction= 1 confidence= [ 0.54907847]
# actual= [1] prediction= 1 confidence= [ 0.38866506]
# actual= [1] prediction= 1 confidence= [ 0.53416508]
# actual= [1] prediction= 1 confidence= [ 0.53395786]
# actual= [1] prediction= 1 confidence= [ 0.43789978]
# actual= [1] prediction= 1 confidence= [ 0.35371746]
# actual= [1] prediction= 1 confidence= [ 0.35764615]
# actual= [1] prediction= 1 confidence= [ 0.4512733]
# actual= [1] prediction= 1 confidence= [ 0.36006065]
# actual= [1] prediction= 1 confidence= [ 0.38960622]
# actual= [2] prediction= 2 confidence= [ 0.99683834]
# actual= [2] prediction= 2 confidence= [ 0.95419523]
# actual= [2] prediction= 2 confidence= [ 0.93889979]
# actual= [2] prediction= 2 confidence= [ 0.94306778]
# actual= [2] prediction= 2 confidence= [ 0.98500125]
# actual= [2] prediction= 2 confidence= [ 0.98196295]
# actual= [2] prediction= 2 confidence= [ 0.9455643]
# actual= [2] prediction= 2 confidence= [ 0.94545312]
# actual= [2] prediction= 2 confidence= [ 0.96839163]
# actual= [2] prediction= 2 confidence= [ 0.96276539]
# actual= [2] prediction= 2 confidence= [ 0.63922009]
# actual= [2] prediction= 2 confidence= [ 0.90744432]
# actual= [2] prediction= 2 confidence= [ 0.88536238]
# actual= [2] prediction= 2 confidence= [ 0.97610113]
# actual= [2] prediction= 2 confidence= [ 0.98939475]
# actual= [2] prediction= 2 confidence= [ 0.92807184]
# actual= [2] prediction= 2 confidence= [ 0.85123397]
# actual= [2] prediction= 2 confidence= [ 0.93646496]
# actual= [2] prediction= 2 confidence= [ 0.99831876]
# actual= [2] prediction= 2 confidence= [ 0.87203633]
# actual= [2] prediction= 2 confidence= [ 0.94033955]
# actual= [2] prediction= 2 confidence= [ 0.94970072]
# actual= [2] prediction= 2 confidence= [ 0.98529314]
# actual= [2] prediction= 2 confidence= [ 0.68203001]
# actual= [2] prediction= 2 confidence= [ 0.91193102]
# actual= [2] prediction= 2 confidence= [ 0.7975671]
# actual= [2] prediction= 2 confidence= [ 0.60633091]
# actual= [2] prediction= 2 confidence= [ 0.64345529]
# actual= [2] prediction= 2 confidence= [ 0.97844203]
# actual= [2] prediction= 1 confidence= [ 0.66037607] <====Prediction error!
# actual= [2] prediction= 2 confidence= [ 0.92149929]
# actual= [2] prediction= 2 confidence= [ 0.610662]
# actual= [2] prediction= 2 confidence= [ 0.98461877]
# actual= [2] prediction= 2 confidence= [ 0.55505686]
# actual= [2] prediction= 2 confidence= [ 0.92957126]
# actual= [2] prediction= 2 confidence= [ 0.93500956]
# actual= [2] prediction= 2 confidence= [ 0.97746025]
# actual= [2] prediction= 2 confidence= [ 0.85421433]
# actual= [2] prediction= 2 confidence= [ 0.61760147]
# actual= [2] prediction= 2 confidence= [ 0.77297342]
# actual= [2] prediction= 2 confidence= [ 0.96936681]
# actual= [2] prediction= 2 confidence= [ 0.70018041]
# actual= [2] prediction= 2 confidence= [ 0.95419523]
# actual= [2] prediction= 2 confidence= [ 0.97613902]
# actual= [2] prediction= 2 confidence= [ 0.97617732]
# actual= [2] prediction= 2 confidence= [ 0.87114509]
# actual= [2] prediction= 2 confidence= [ 0.87015369]
# actual= [2] prediction= 2 confidence= [ 0.79694224]
# actual= [2] prediction= 2 confidence= [ 0.9507265]
# actual= [2] prediction= 2 confidence= [ 0.8566945]
